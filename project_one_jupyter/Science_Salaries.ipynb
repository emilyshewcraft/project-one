# %%
from matplotlib import pyplot as plt
from scipy import stats
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# The path to our CSV file
Science_Salaries = Path("C:\\Users\Roses\Documents\Project_1\project-one\Resources\Data_Science_Salaries_Clean.csv")

# Read our Crowdfunding data into pandas
Science_Salaries_df = pd.read_csv(Science_Salaries)
Science_Salaries_df.head()
# Out:
#    Unnamed: 0       Job Title Employment Type Experience Level  \
# 0           0   Data Engineer       Full-Time           Senior
# 1           1   Data Engineer       Full-Time           Senior
# 2           2   Data Engineer       Full-Time           Senior
# 3           3   Data Engineer       Full-Time           Senior
# 4           4  Data Scientist       Full-Time           Senior
#
#   Expertise Level  Salary       Salary Currency Company Location  \
# 0          Expert  210000  United States Dollar    United States
# 1          Expert  165000  United States Dollar    United States
# 2          Expert  185900  United States Dollar    United States
# 3          Expert  129300  United States Dollar    United States
# 4          Expert  140000  United States Dollar    United States
#
#    Salary in USD Employee Residence Company Size  Year
# 0         210000      United States       Medium  2023
# 1         165000      United States       Medium  2023
# ...

# %%
job_title_count= Science_Salaries_df.groupby("Job Title")
job_title_count["Job Title"].count().sort_values(ascending=False)
# Out:
# Job Title
# Data Engineer                702
# Data Scientist               635
# Data Analyst                 459
# Machine Learning Engineer    300
# Analytics Engineer           132
# Name: Job Title, dtype: int64

# %%
country_count= Science_Salaries_df.groupby("Employee Residence")
country_count["Employee Residence"].count().sort_values(ascending=False)
# Out:
# Employee Residence
# United States                1698
# United Kingdom                183
# Canada                         66
# Spain                          39
# Germany                        30
# France                         28
# India                          25
# Netherlands                    11
# Australia                       9
# Greece                          9
# Portugal                        8
# Brazil                          8
# Mexico                          7
# Argentina                       7
# Colombia                        7
# Ireland                         6
# Poland                          4
# Latvia                          4
# Estonia                         4
# Puerto Rico                     4
# Switzerland                     4
# Belgium                         4
# Austria                         3
# Japan                           3
# Italy                           3
# Philippines                     3
# Slovenia                        3
# ...

# %%
expertise_level_count= Science_Salaries_df.groupby("Expertise Level")
expertise_level_count["Expertise Level"].count().sort_values(ascending=False)
# Out:
# Expertise Level
# Expert          1424
# Intermediate     537
# Junior           183
# Director          84
# Name: Expertise Level, dtype: int64

# %%
expertise_level_dir = Science_Salaries_df.loc[Science_Salaries_df["Expertise Level"] == "Director" , :]
expertise_level_dir.head(10)
# Out:
#      Unnamed: 0       Job Title Employment Type Experience Level  \
# 38           59   Data Engineer       Full-Time        Executive
# 39           60   Data Engineer       Full-Time        Executive
# 91          131   Data Engineer       Full-Time        Executive
# 92          132   Data Engineer       Full-Time        Executive
# 113         167   Data Engineer       Full-Time        Executive
# 114         168   Data Engineer       Full-Time        Executive
# 131         189  Data Scientist       Full-Time        Executive
# 132         190  Data Scientist       Full-Time        Executive
# 205         283   Data Engineer       Full-Time        Executive
# 206         284   Data Engineer       Full-Time        Executive
#
#     Expertise Level  Salary       Salary Currency Company Location  \
# 38         Director  205785  United States Dollar   United Kingdom
# 39         Director  123471  United States Dollar   United Kingdom
# ...

# %%
expertise_level_jr = Science_Salaries_df.loc[Science_Salaries_df["Expertise Level"] == "Junior" , :]
expertise_level_jr.head(10)
# Out:
#      Unnamed: 0       Job Title Employment Type Experience Level  \
# 173         241    Data Analyst       Full-Time            Entry
# 174         242    Data Analyst       Full-Time            Entry
# 179         249    Data Analyst       Full-Time            Entry
# 180         250    Data Analyst       Full-Time            Entry
# 231         319   Data Engineer       Full-Time            Entry
# 232         320   Data Engineer       Full-Time            Entry
# 253         348    Data Analyst       Full-Time            Entry
# 391         555    Data Analyst       Full-Time            Entry
# 392         556    Data Analyst       Full-Time            Entry
# 401         566  Data Scientist       Full-Time            Entry
#
#     Expertise Level  Salary         Salary Currency Company Location  \
# 173          Junior   90000    United States Dollar    United States
# 174          Junior   60000    United States Dollar    United States
# ...

# %%
title_data_analyst = Science_Salaries_df.loc[Science_Salaries_df["Job Title"] == "Data Analyst" , :]
title_data_analyst.head(10)
# Out:
#     Unnamed: 0     Job Title Employment Type Experience Level Expertise Level  \
# 20          22  Data Analyst       Full-Time           Senior          Expert
# 21          23  Data Analyst       Full-Time           Senior          Expert
# 36          53  Data Analyst       Full-Time           Senior          Expert
# 37          54  Data Analyst       Full-Time           Senior          Expert
# 47          75  Data Analyst       Full-Time           Senior          Expert
# 48          76  Data Analyst       Full-Time           Senior          Expert
# 63          96  Data Analyst       Full-Time           Senior          Expert
# 64          97  Data Analyst       Full-Time           Senior          Expert
# 87         127  Data Analyst       Full-Time           Senior          Expert
# 88         128  Data Analyst       Full-Time           Senior          Expert
#
#     Salary       Salary Currency Company Location  Salary in USD  \
# ...

# %%
job_title_clean = Science_Salaries_df.loc[Science_Salaries_df["Job Title"].isin(["Data Engineer",
                                            "Data Scientist", "Data Analyst", "Machine Learning Engineer",
                                            "Analytics Engineer"])]
job_title_clean
# Out:
#       Unnamed: 0                  Job Title Employment Type Experience Level  \
# 0              0              Data Engineer       Full-Time           Senior
# 1              1              Data Engineer       Full-Time           Senior
# 2              2              Data Engineer       Full-Time           Senior
# 3              3              Data Engineer       Full-Time           Senior
# 4              4             Data Scientist       Full-Time           Senior
# ...          ...                        ...             ...              ...
# 2223        3289  Machine Learning Engineer       Full-Time           Senior
# 2224        3291             Data Scientist       Full-Time              Mid
# 2225        3293              Data Engineer       Full-Time              Mid
# 2226        3295             Data Scientist       Full-Time           Senior
# 2227        3297             Data Scientist       Full-Time            Entry
#
# ...
